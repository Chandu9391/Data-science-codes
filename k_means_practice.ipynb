# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandu9391/Data-science-codes/blob/main/k_means_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
univ = pd.read_csv('/content/Universities.csv')

# %%
univ.head()
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# 0     Brown  1310     89      22       13     22704        94
# 1   CalTech  1415    100      25        6     63575        81
# 2       CMU  1260     62      59        9     25026        72
# 3  Columbia  1310     76      24       12     31510        88
# 4   Cornell  1280     83      33       13     21864        90

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler_univ = scaler.fit_transform(univ.iloc[:,1:])

# %%
scaler_univ
# Out:
# array([[ 0.41028362,  0.6575195 , -0.88986682,  0.07026045, -0.33141256,
#          0.82030265],
#        [ 1.39925928,  1.23521235, -0.73465749, -1.68625071,  2.56038138,
#         -0.64452351],
#        [-0.06065717, -0.76045386,  1.02438157, -0.93346022, -0.16712136,
#         -1.65863393],
#        [ 0.41028362, -0.02520842, -0.78639393, -0.18066972,  0.29164871,
#          0.14422904],
#        [ 0.12771914,  0.34241431, -0.32076595,  0.07026045, -0.39084607,
#          0.36958691],
#        [ 0.69284809,  0.6575195 , -0.83813038, -0.68253005,  0.33778044,
#          0.93298158],
#        [ 0.4573777 ,  0.71003703, -0.47597528, -0.18066972,  0.29695528,
#          0.93298158],
#        [-0.10775125, -0.13024348, -0.78639393, -0.18066972, -0.51381683,
#          0.59494478],
#        [ 1.25797704,  0.76255456, -1.30375836, -0.43159988,  0.85874344,
#          1.15833946],
#        [ 0.36318954, -0.07772595,  0.24833493, -1.43532055,  2.21481798,
#          0.0315501 ],
# ...

# %%
w = []
for i in range(1,11):
  kmeans = KMeans(n_clusters = i, random_state = 42)
  kmeans.fit(scaler_univ)
  w.append(kmeans.inertia_)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
w
# Out:
# [150.0,
#  64.1452839501027,
#  44.531761731450956,
#  33.654341806512235,
#  26.907807926289365,
#  22.452524599848378,
#  18.750021301705342,
#  16.00657366889506,
#  13.51107215641083,
#  10.729002092323686]

# %%
plt.plot(range(1,11),w)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('w')
plt.show()

# %%
from sklearn.cluster import KMeans
cluster_new = KMeans(4, random_state = 42)
cluster_new.fit(scaler_univ)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# KMeans(n_clusters=4, random_state=42)

# %%
univ['cluster_new'] = cluster_new.labels_

# %%
univ['cluster_new']
# Out:
# 0     2
# 1     3
# 2     0
# 3     2
# 4     0
# 5     2
# 6     2
# 7     0
# 8     2
# 9     3
# 10    2
# 11    0
# 12    0
# 13    1
# 14    2
# 15    1
# 16    2
# 17    1
# 18    0
# 19    0
# 20    0
# 21    0
# 22    0
# 23    1
# 24    2
# Name: cluster_new, dtype: int32

# %%
cluster_new.cluster_centers_
# Out:
# array([[-0.12658888,  0.06407139,  0.2224667 ,  0.04516743, -0.38064332,
#          0.02028221],
#        [-1.93029211, -1.98148647,  1.59348244,  1.63857398, -1.23359906,
#         -1.68680366],
#        [ 0.80273428,  0.68086062, -0.90136381, -0.43159988,  0.44062556,
#          0.79526289],
#        [ 0.88122441,  0.5787432 , -0.24316128, -1.56078563,  2.38759968,
#         -0.3064867 ]])

# %%
univ.head()
# Out:
#        Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate  cluster_new
# 0     Brown  1310     89      22       13     22704        94            2
# 1   CalTech  1415    100      25        6     63575        81            3
# 2       CMU  1260     62      59        9     25026        72            0
# 3  Columbia  1310     76      24       12     31510        88            2
# 4   Cornell  1280     83      33       13     21864        90            0

# %%
univ.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25 entries, 0 to 24
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Univ         25 non-null     object
#  1   SAT          25 non-null     int64
#  2   Top10        25 non-null     int64
#  3   Accept       25 non-null     int64
#  4   SFRatio      25 non-null     int64
#  5   Expenses     25 non-null     int64
#  6   GradRate     25 non-null     int64
#  7   cluster_new  25 non-null     int32
# dtypes: int32(1), int64(6), object(1)
# memory usage: 1.6+ KB

# %%
univ['cluster_new']
# Out:
# 1.12

# %%
univ.groupby('cluster_new').max()
# Out:
#                      Univ   SAT  Top10  Accept  SFRatio  Expenses  GradRate
# cluster_new
# 0                     UVA  1290     95      68       17     38380        94
# 1              UWisconsin  1085     49      90       25     11857        80
# 2                    Yale  1400     95      30       13     43514        97
# 3            JohnsHopkins  1415    100      44        7     63575        87

# %%
univ.columns
# Out:
# Index(['Univ', 'SAT', 'Top10', 'Accept', 'SFRatio', 'Expenses', 'GradRate',
#        'cluster_new'],
#       dtype='object')
